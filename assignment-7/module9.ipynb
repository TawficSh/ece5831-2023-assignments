# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
#data_filename = "dogs-vs-cats.zip"
data_from_kaggle = "data-from-kaggle/train"
#data_from_kaggle_test = "data-from-kaggle/test1"
data_dirname = "dogs-vs-cats"

# %%
import os
import shutil

# %%
# subset_name: train, validation, test
def make_dataset(subset_name, start_idx, end_idx):
    for category in { "cat", "dog" }:
       # data_dirname/subset_name/categoroy 
       dir = f"{data_dirname}/{subset_name}/{category}"
       # print(dir)
       os.makedirs(dir)
       fnames = [f"{category}.{i}.jpg" for i in range(start_idx, end_idx)]
       # print(fnames)
       for fname in fnames: 
             shutil.copyfile(src=f"{data_from_kaggle}/{fname}", dst=f"{dir}/{fname}")

# %%
make_dataset("train", 0, 1000)
make_dataset("validation", 7501, 8001)
make_dataset("test", 10001, 11001)

# %%
from tensorflow.keras.utils import image_dataset_from_directory

data_dirname = "dogs-vs-cats"
batch_size = 32
train_dataset = image_dataset_from_directory(f"{data_dirname}/train", image_size=(200, 180), batch_size=batch_size)
validation_dataset = image_dataset_from_directory(f"{data_dirname}/validation", image_size=(200, 180), batch_size=batch_size)
test_dataset = image_dataset_from_directory(f"{data_dirname}/test", image_size=(200, 180), batch_size=batch_size)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import dogscatspre as dcp
import dogscatsfine as dcf

dogs_cats_pre = dcp.DogsCatsPre()
dogs_cats_fine = dcf.DogsCatsFine()

# %%
dogs_cats_pre.build_model()

# %%
dogs_cats_pre.train("model_Tawfic")
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 8.7973 - accuracy: 0.8880INFO:tensorflow:Assets written to: model_Tawfic\assets
# INFO:tensorflow:Assets written to: model_Tawfic\assets
# 63/63 [==============================] - 244s 4s/step - loss: 8.7973 - accuracy: 0.8880 - val_loss: 0.9115 - val_accuracy: 0.9340
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.7538 - accuracy: 0.9605INFO:tensorflow:Assets written to: model_Tawfic\assets
# INFO:tensorflow:Assets written to: model_Tawfic\assets
# 63/63 [==============================] - 232s 4s/step - loss: 0.7538 - accuracy: 0.9605 - val_loss: 0.6675 - val_accuracy: 0.9400
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.9695INFO:tensorflow:Assets written to: model_Tawfic\assets
# ...

# %%
test_images_dogs1 = [os.path.join(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\dog", img) for img in os.listdir(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\dog") if img.endswith(('.jpg', '.jpeg', '.png'))]
for i in test_images_dogs1:
 dogs_cats_pre.predict("model_Tawfic",i)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[1.]]
# 1/1 [==============================] - 0s 145ms/step
# [[1.]]
# 1/1 [==============================] - 0s 161ms/step
# [[1.]]
# 1/1 [==============================] - 0s 237ms/step
# [[1.]]
# 1/1 [==============================] - 0s 140ms/step
# [[1.]]
# 1/1 [==============================] - 0s 140ms/step
# [[1.]]
# 1/1 [==============================] - 0s 176ms/step
# [[1.]]
# 1/1 [==============================] - 0s 179ms/step
# [[1.]]
# 1/1 [==============================] - 0s 214ms/step
# [[0.16332674]]
# 1/1 [==============================] - 0s 160ms/step
# [[1.]]
# 1/1 [==============================] - 0s 146ms/step
# [[1.]]
# 1/1 [==============================] - 0s 153ms/step
# [[1.]]
# 1/1 [==============================] - 0s 147ms/step
# [[1.]]
# 1/1 [==============================] - 0s 206ms/step
# [[1.]]
# 1/1 [==============================] - 0s 143ms/step
# [[1.]]
# ...

# %%
test_images_cats1 = [os.path.join(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\cat", img) for img in os.listdir(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\cat") if img.endswith(('.jpg', '.jpeg', '.png'))]
for i in test_images_cats1:
    dogs_cats_pre.predict("model_Tawfic",i)
# Out:
# 1/1 [==============================] - 0s 105ms/step
# [[0.]]
# 1/1 [==============================] - 0s 110ms/step
# [[0.]]
# 1/1 [==============================] - 0s 126ms/step
# [[0.]]
# 1/1 [==============================] - 0s 117ms/step
# [[0.]]
# 1/1 [==============================] - 0s 120ms/step
# [[3.7156105e-28]]
# 1/1 [==============================] - 0s 118ms/step
# [[0.]]
# 1/1 [==============================] - 0s 118ms/step
# [[0.]]
# 1/1 [==============================] - 0s 110ms/step
# [[0.]]
# 1/1 [==============================] - 0s 118ms/step
# [[0.]]
# 1/1 [==============================] - 0s 119ms/step
# [[0.99999774]]
# 1/1 [==============================] - 0s 118ms/step
# [[8.253263e-27]]
# 1/1 [==============================] - 0s 109ms/step
# [[0.]]
# 1/1 [==============================] - 0s 103ms/step
# [[0.99999815]]
# 1/1 [==============================] - 0s 128ms/step
# [[3.552109e-27]]
# 1/1 [==============================] - 0s 118ms/step
# ...

# %%
test_loss, test_accuracy = dogs_cats_pre.model.evaluate(test_dataset)
print(f"DogsCats Model - Test Accuracy: {test_accuracy}")
# Out:
# 63/63 [==============================] - 162s 3s/step - loss: 1.2338 - accuracy: 0.9505
# DogsCats Model - Test Accuracy: 0.9505000114440918

# %%
dogs_cats_fine.build_model()

# %%
dogs_cats_fine.train("model_Tawfic2")
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 8.6648 - accuracy: 0.8850INFO:tensorflow:Assets written to: model_Tawfic2\assets
# INFO:tensorflow:Assets written to: model_Tawfic2\assets
# 63/63 [==============================] - 242s 4s/step - loss: 8.6648 - accuracy: 0.8850 - val_loss: 1.5423 - val_accuracy: 0.9340
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.8349 - accuracy: 0.9605INFO:tensorflow:Assets written to: model_Tawfic2\assets
# INFO:tensorflow:Assets written to: model_Tawfic2\assets
# 63/63 [==============================] - 244s 4s/step - loss: 0.8349 - accuracy: 0.9605 - val_loss: 3.2487 - val_accuracy: 0.8510
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.5114 - accuracy: 0.9695INFO:tensorflow:Assets written to: model_Tawfic2\assets
# ...

# %%
test_images_dogs2 = [os.path.join(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\dog", img) for img in os.listdir(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\dog") if img.endswith(('.jpg', '.jpeg', '.png'))]
for i in test_images_dogs2:
 dogs_cats_fine.predict("model_Tawfic2",i)
# Out:
# 1/1 [==============================] - 0s 210ms/step
# [[1.]]
# 1/1 [==============================] - 0s 98ms/step
# [[1.]]
# 1/1 [==============================] - 0s 96ms/step
# [[1.]]
# 1/1 [==============================] - 0s 90ms/step
# [[1.]]
# 1/1 [==============================] - 0s 104ms/step
# [[1.]]
# 1/1 [==============================] - 0s 108ms/step
# [[1.]]
# 1/1 [==============================] - 0s 111ms/step
# [[1.]]
# 1/1 [==============================] - 0s 110ms/step
# [[1.]]
# 1/1 [==============================] - 0s 111ms/step
# [[0.9999962]]
# 1/1 [==============================] - 0s 110ms/step
# [[1.]]
# 1/1 [==============================] - 0s 104ms/step
# [[1.]]
# 1/1 [==============================] - 0s 109ms/step
# [[1.]]
# 1/1 [==============================] - 0s 108ms/step
# [[1.]]
# 1/1 [==============================] - 0s 103ms/step
# [[1.]]
# 1/1 [==============================] - 0s 114ms/step
# [[1.]]
# ...

# %%
test_images_cats2 = [os.path.join(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\cat", img) for img in os.listdir(r"C:\Users\ACER\OneDrive\Desktop\ece5831-2023-assignments\ece5831-2023-assignments\assignment-8\dogs-vs-cats\test\cat") if img.endswith(('.jpg', '.jpeg', '.png'))]
for i in test_images_cats2:
    dogs_cats_fine.predict("model_Tawfic2",i)
# Out:
# 1/1 [==============================] - 0s 106ms/step
# [[0.]]
# 1/1 [==============================] - 0s 104ms/step
# [[0.]]
# 1/1 [==============================] - 0s 100ms/step
# [[0.]]
# 1/1 [==============================] - 0s 125ms/step
# [[0.]]
# 1/1 [==============================] - 0s 119ms/step
# [[1.8493446e-35]]
# 1/1 [==============================] - 0s 122ms/step
# [[0.]]
# 1/1 [==============================] - 0s 118ms/step
# [[0.]]
# 1/1 [==============================] - 0s 127ms/step
# [[0.]]
# 1/1 [==============================] - 0s 117ms/step
# [[0.]]
# 1/1 [==============================] - 0s 112ms/step
# [[1.]]
# 1/1 [==============================] - 0s 113ms/step
# [[7.843242e-34]]
# 1/1 [==============================] - 0s 106ms/step
# [[0.]]
# 1/1 [==============================] - 0s 125ms/step
# [[1.]]
# 1/1 [==============================] - 0s 118ms/step
# [[1.2810247e-25]]
# 1/1 [==============================] - 0s 119ms/step
# [[0.]]
# ...

# %%
test_loss, test_accuracy = dogs_cats_fine.model.evaluate(test_dataset)
print(f"DogsCats Model - Test Accuracy: {test_accuracy}")
# Out:
# 63/63 [==============================] - 249s 4s/step - loss: 1.2305 - accuracy: 0.9530
# DogsCats Model - Test Accuracy: 0.953000009059906

# %%
import matplotlib.pyplot as plt

# %%
import tensorflow

# %%
def visualize_predictions(model, dataset, class_names):
    plt.figure(figsize=(15, 15))
    for images, labels in dataset.take(1):
        predictions = model.predict(images)
        for i in range(10):
            ax = plt.subplot(2, 5, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            predicted_label = class_names[tensorflow.argmax(predictions[i])]
            true_label = class_names[labels[i]]
            plt.title(f'Predicted: {predicted_label}\nTrue: {true_label}')
            plt.axis("off")

visualize_predictions(dogs_cats_pre.model, test_dataset, train_dataset.class_names)
visualize_predictions(dogs_cats_fine.model, test_dataset, train_dataset.class_names)
plt.show()
# Out:
# ...
# 1/1 [==============================] - 5s 5s/step
